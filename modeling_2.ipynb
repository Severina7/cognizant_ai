# %% [markdown]
# <a href="https://colab.research.google.com/github/Severina7/cognizant_ai/blob/main/modeling_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 3 - Modeling
#
# This notebook will get you started by helping you to load the data, but then it'll be up to you to complete the task! If you need help, refer to the `modeling_walkthrough.ipynb` notebook.
#
#
# ## Section 1 - Setup
#
# First, we need to mount this notebook to our Google Drive folder, in order to access the CSV data file. If you haven't already, watch this video https://www.youtube.com/watch?v=woHxvbBLarQ to help you mount your Google Drive folder.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We want to use dataframes once again to store and manipulate the data.

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ---
#
# ## Section 2 - Data loading
#
# Similar to before, let's load our data from Google Drive for the 3 datasets provided. Be sure to upload the datasets into Google Drive, so that you can access them here.

# %%
path = '/content/drive/MyDrive/cognizant_ds_pipeline/'

sales_df = pd.read_csv(f"{path}/sales.csv")
sales_df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')
sales_df.head()
# Out:
#                          transaction_id            timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# 1         1   3.99     e-wallet
# 2         2   0.38     e-wallet
# ...

# %%
stock_df = pd.read_csv(f"{path}sensor_stock_levels.csv")
stock_df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')
stock_df.head()
# Out:
#                                      id            timestamp  \
# 0  4220e505-c247-478d-9831-6b9f87a4488a  2022-03-07 12:13:02
# 1  f2612b26-fc82-49ea-8940-0751fdd4d9ef  2022-03-07 16:39:46
# 2  989a287f-67e6-4478-aa49-c3a35dac0e2e  2022-03-01 18:17:43
# 3  af8e5683-d247-46ac-9909-1a77bdebefb2  2022-03-02 14:29:09
# 4  08a32247-3f44-4002-85fb-c198434dd4bb  2022-03-02 13:46:18
#
#                              product_id  estimated_stock_pct
# 0  f658605e-75f3-4fed-a655-c0903f344427                 0.75
# 1  de06083a-f5c0-451d-b2f4-9ab88b52609d                 0.48
# 2  ce8f3a04-d1a4-43b1-a7c2-fa1b8e7674c8                 0.58
# 3  c21e3ba9-92a3-4745-92c2-6faef73223f7                 0.79
# 4  7f478817-aa5b-44e9-9059-8045228c9eb0                 0.22

# %%
temp_df = pd.read_csv(f"{path}sensor_storage_temperature.csv")
temp_df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')
temp_df.head()
# Out:
#                                      id            timestamp  temperature
# 0  d1ca1ef8-0eac-42fc-af80-97106efc7b13  2022-03-07 15:55:20         2.96
# 1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18  2022-03-01 09:18:22         1.88
# 2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3  2022-03-04 15:12:26         1.78
# 3  9500357b-ce15-424a-837a-7677b386f471  2022-03-02 12:30:42         2.18
# 4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa  2022-03-05 09:09:33         1.38

# %% [markdown]
# Now it's up to you, refer back to the steps in your strategic plan to complete this task. Good luck!

# %% [markdown]
# **I. Data cleaning and prepping**

# %% [markdown]
# 1. Cleaning

# %%
sales_df.shape, stock_df.shape, temp_df.shape
# Out:
# ((7829, 9), (15000, 4), (23890, 3))

# %% [markdown]
# In order to have all the data in one place I'll need to merge DataFrames.

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7829 entries, 0 to 7828
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   transaction_id  7829 non-null   object
#  1   timestamp       7829 non-null   object
#  2   product_id      7829 non-null   object
#  3   category        7829 non-null   object
#  4   customer_type   7829 non-null   object
#  5   unit_price      7829 non-null   float64
#  6   quantity        7829 non-null   int64
#  7   total           7829 non-null   float64
#  8   payment_type    7829 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 550.6+ KB

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   15000 non-null  object
#  1   timestamp            15000 non-null  object
#  2   product_id           15000 non-null  object
#  3   estimated_stock_pct  15000 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 468.9+ KB

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23890 entries, 0 to 23889
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           23890 non-null  object
#  1   timestamp    23890 non-null  object
#  2   temperature  23890 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 560.0+ KB

# %% [markdown]
# There seem to be no nulls in the data.
# However, the timestamp column has an object datatype and needs to be changed to DateTime format

# %%
def convert_to_datetime(data: pd.DataFrame = None, column: str = None):
  dummy = data.copy()
  dummy[column] = pd.to_datetime(dummy[column], format='%Y-%m-%d %H:%M:%S')
  return dummy

# %%
sales_df = convert_to_datetime(sales_df, 'timestamp')
sales_df.head()
# Out:
#                          transaction_id           timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed 2022-03-02 09:51:38
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60 2022-03-06 10:33:59
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea 2022-03-04 17:20:21
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4 2022-03-02 17:23:58
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514 2022-03-05 14:32:43
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# 1         1   3.99     e-wallet
# 2         2   0.38     e-wallet
# ...

# %%
stock_df = convert_to_datetime(stock_df, 'timestamp')
stock_df.head()
# Out:
#                                      id           timestamp  \
# 0  4220e505-c247-478d-9831-6b9f87a4488a 2022-03-07 12:13:02
# 1  f2612b26-fc82-49ea-8940-0751fdd4d9ef 2022-03-07 16:39:46
# 2  989a287f-67e6-4478-aa49-c3a35dac0e2e 2022-03-01 18:17:43
# 3  af8e5683-d247-46ac-9909-1a77bdebefb2 2022-03-02 14:29:09
# 4  08a32247-3f44-4002-85fb-c198434dd4bb 2022-03-02 13:46:18
#
#                              product_id  estimated_stock_pct
# 0  f658605e-75f3-4fed-a655-c0903f344427                 0.75
# 1  de06083a-f5c0-451d-b2f4-9ab88b52609d                 0.48
# 2  ce8f3a04-d1a4-43b1-a7c2-fa1b8e7674c8                 0.58
# 3  c21e3ba9-92a3-4745-92c2-6faef73223f7                 0.79
# 4  7f478817-aa5b-44e9-9059-8045228c9eb0                 0.22

# %%
temp_df = convert_to_datetime(temp_df, 'timestamp')
temp_df.head()
# Out:
#                                      id           timestamp  temperature
# 0  d1ca1ef8-0eac-42fc-af80-97106efc7b13 2022-03-07 15:55:20         2.96
# 1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18 2022-03-01 09:18:22         1.88
# 2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3 2022-03-04 15:12:26         1.78
# 3  9500357b-ce15-424a-837a-7677b386f471 2022-03-02 12:30:42         2.18
# 4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa 2022-03-05 09:09:33         1.38

# %% [markdown]
# 2. Prepping (timestamp and merge)

# %% [markdown]
# I  need to make the timestamp hourly because that is the periodicity the client wants.

# %%
from datetime import datetime

# %%
def convert_timestamp_to_hourly(data: pd.DataFrame = None, column: str = None):
  dummy = data.copy()
  new_ts = dummy[column].tolist()
  new_ts = [i.strftime('%Y-%m-%d %H:00:00') for i in new_ts]
  new_ts = [datetime.strptime(i, '%Y-%m-%d %H:00:00') for i in new_ts]
  dummy[column] = new_ts
  return dummy

# %%
# Converting timestamp to an hourly increment for all 3 DataFrames
sales_df = convert_timestamp_to_hourly(sales_df, 'timestamp')
sales_df.head()
# Out:
#                          transaction_id           timestamp  \
# 0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed 2022-03-02 09:00:00
# 1  931ad550-09e8-4da6-beaa-8c9d17be9c60 2022-03-06 10:00:00
# 2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea 2022-03-04 17:00:00
# 3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4 2022-03-02 17:00:00
# 4  a81a6cd3-5e0c-44a2-826c-aea43e46c514 2022-03-05 14:00:00
#
#                              product_id category customer_type  unit_price  \
# 0  3bc6c1ea-0198-46de-9ffd-514ae3338713    fruit          gold        3.99
# 1  ad81b46c-bf38-41cf-9b54-5fe7f5eba93e    fruit      standard        3.99
# 2  7c55cbd4-f306-4c04-a030-628cbe7867c1    fruit       premium        0.19
# 3  80da8348-1707-403f-8be7-9e6deeccc883    fruit          gold        0.19
# 4  7f5e86e6-f06f-45f6-bf44-27b095c9ad1d    fruit         basic        4.49
#
#    quantity  total payment_type
# 0         2   7.98     e-wallet
# 1         1   3.99     e-wallet
# 2         2   0.38     e-wallet
# ...

# %%
stock_df = convert_timestamp_to_hourly(stock_df, 'timestamp')
stock_df.head()
# Out:
#                                      id           timestamp  \
# 0  4220e505-c247-478d-9831-6b9f87a4488a 2022-03-07 12:00:00
# 1  f2612b26-fc82-49ea-8940-0751fdd4d9ef 2022-03-07 16:00:00
# 2  989a287f-67e6-4478-aa49-c3a35dac0e2e 2022-03-01 18:00:00
# 3  af8e5683-d247-46ac-9909-1a77bdebefb2 2022-03-02 14:00:00
# 4  08a32247-3f44-4002-85fb-c198434dd4bb 2022-03-02 13:00:00
#
#                              product_id  estimated_stock_pct
# 0  f658605e-75f3-4fed-a655-c0903f344427                 0.75
# 1  de06083a-f5c0-451d-b2f4-9ab88b52609d                 0.48
# 2  ce8f3a04-d1a4-43b1-a7c2-fa1b8e7674c8                 0.58
# 3  c21e3ba9-92a3-4745-92c2-6faef73223f7                 0.79
# 4  7f478817-aa5b-44e9-9059-8045228c9eb0                 0.22

# %%
temp_df = convert_timestamp_to_hourly(temp_df, 'timestamp')
temp_df.head()
# Out:
#                                      id           timestamp  temperature
# 0  d1ca1ef8-0eac-42fc-af80-97106efc7b13 2022-03-07 15:00:00         2.96
# 1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18 2022-03-01 09:00:00         1.88
# 2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3 2022-03-04 15:00:00         1.78
# 3  9500357b-ce15-424a-837a-7677b386f471 2022-03-02 12:00:00         2.18
# 4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa 2022-03-05 09:00:00         1.38

# %% [markdown]
# ### - **Exploring the data further**

# %% [markdown]
# Exploring the data to have a high level view of its shape in all DataFrames before combining them and doing some feature engineering.

# %%
import matplotlib.pyplot as plt

plt.title("The temperature distribution")
temp_df.temperature.hist()
plt.show()

# %%
# Temperatue average
temp_df.temperature.mean()
# Out:
# -0.20707450816241102

# %%
plt.title("Stock percentage distribution")
stock_df.estimated_stock_pct.hist()
plt.show()

# %%
# Stock levels average
stock_df.estimated_stock_pct.mean()
# Out:
# 0.5

# %%
import seaborn as sns
def plot_continuous_distribution(data: pd.DataFrame = None, column: str = None, height: int = 12):
  _ = sns.displot(data, x=column, kde=True, height=height, aspect=height/5,
                  palette='colorblind').set(title=f'Distribution of {column}');

# %%
sales_df.columns.to_list()
# Out:
# ['transaction_id',
#  'timestamp',
#  'product_id',
#  'category',
#  'customer_type',
#  'unit_price',
#  'quantity',
#  'total',
#  'payment_type']

# %%
plot_continuous_distribution(sales_df, ['category', 'customer_type', 'unit_price', 'quantity', 'total', 'payment_type'])

# %%
def plot_categorical_distribution(data: pd.DataFrame = None, column: str = None, height: int = 8, aspect: int = 2):
  plot = sns.catplot(
      data=data,
      x=column, 
      kind='count', 
      height=height, aspect=aspect, palette='colorblind').set(title=f'Distribution of {column}')
  plot.set_xticklabels(rotation=90)

# %%
plot_categorical_distribution(sales_df, 'category')

# %% [markdown]
# The data in general does not seem different from the set I had before. The difference is the new sets from temperatures and storage which we can see the plots in the previous section. I will go ahead and aggregate the data and split it.

# %% [markdown]
# ## **Merging and aggregating data**

# %% [markdown]
# - **For sales**

# %%
sales_agg = sales_df.groupby(['timestamp', 'product_id']).agg({'quantity': 'sum'}).reset_index()
sales_agg.head()
# Out:
#             timestamp                            product_id  quantity
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03         3
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0         3
# 2 2022-03-01 09:00:00  03a2557a-aa12-4add-a6d4-77dc36342067         3
# 3 2022-03-01 09:00:00  049b2171-0eeb-4a3e-bf98-0c290c7821da         7
# 4 2022-03-01 09:00:00  04da844d-8dba-4470-9119-e534d52a03a0        11

# %% [markdown]
# - **For stock percent**

# %%
stock_agg = stock_df.groupby(['timestamp', 'product_id']).agg({'estimated_stock_pct': 'mean'}).reset_index()
stock_agg.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct
# 0                 0.89
# 1                 0.14
# 2                 0.67
# 3                 0.82
# 4                 0.05

# %% [markdown]
# - **For temperatures**

# %%
temp_agg = temp_df.groupby(['timestamp']).agg({'temperature': 'mean'}).reset_index()
temp_agg.head()
# Out:
#             timestamp  temperature
# 0 2022-03-01 09:00:00    -0.028850
# 1 2022-03-01 10:00:00     1.284314
# 2 2022-03-01 11:00:00    -0.560000
# 3 2022-03-01 12:00:00    -0.537721
# 4 2022-03-01 13:00:00    -0.188734

# %% [markdown]
# - **Data merging**

# %%
merged_df = stock_agg.merge(sales_agg, on=['timestamp', 'product_id'], how='left')
merged_df.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct  quantity
# 0                 0.89       3.0
# 1                 0.14       3.0
# 2                 0.67       NaN
# 3                 0.82       NaN
# 4                 0.05       NaN

# %% [markdown]
# - **Checking the quantity column**

# %%
print(merged_df['quantity'].isnull().sum())
print(merged_df['quantity'].isnull().sum()*100/(len(merged_df)))
# Out:
# 7778
# 71.71968649147072

# %%
merged_df = merged_df.merge(temp_agg, on='timestamp', how='left')
merged_df.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct  quantity  temperature
# 0                 0.89       3.0     -0.02885
# 1                 0.14       3.0     -0.02885
# 2                 0.67       NaN     -0.02885
# 3                 0.82       NaN     -0.02885
# 4                 0.05       NaN     -0.02885

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10845 entries, 0 to 10844
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            10845 non-null  datetime64[ns]
#  1   product_id           10845 non-null  object
#  2   estimated_stock_pct  10845 non-null  float64
#  3   quantity             3067 non-null   float64
#  4   temperature          10845 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 508.4+ KB

# %% [markdown]
# The quantity column has 71% percent of null values that correspond to missing values from the estimated_stock_pct column which shows that for these products in storage there was no sale at the timestamp indicated.

# %%
# Filling missing values
merged_df['quantity'] = merged_df['quantity'].fillna(0)
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10845 entries, 0 to 10844
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            10845 non-null  datetime64[ns]
#  1   product_id           10845 non-null  object
#  2   estimated_stock_pct  10845 non-null  float64
#  3   quantity             10845 non-null  float64
#  4   temperature          10845 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 508.4+ KB

# %% [markdown]
# Creating some new features to add depth to the model

# %%
product_categories = sales_df[['product_id', 'category']]
product_categories = product_categories.drop_duplicates()
product_price = sales_df[['product_id', 'unit_price']]
product_price = product_price.drop_duplicates()

# %% [markdown]
# Adding them to the DataFrame

# %%
merged_df = merged_df.merge(product_categories, on="product_id", how="left")
merged_df.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct  quantity  temperature       category
# 0                 0.89       3.0     -0.02885        kitchen
# 1                 0.14       3.0     -0.02885     vegetables
# 2                 0.67       0.0     -0.02885  baby products
# 3                 0.82       0.0     -0.02885      beverages
# 4                 0.05       0.0     -0.02885           pets

# %%
merged_df = merged_df.merge(product_price, on="product_id", how="left")
merged_df.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct  quantity  temperature       category  unit_price
# 0                 0.89       3.0     -0.02885        kitchen       11.19
# 1                 0.14       3.0     -0.02885     vegetables        1.49
# 2                 0.67       0.0     -0.02885  baby products       14.19
# 3                 0.82       0.0     -0.02885      beverages       20.19
# 4                 0.05       0.0     -0.02885           pets        8.19

# %%
# Checking null values again
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10845 entries, 0 to 10844
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            10845 non-null  datetime64[ns]
#  1   product_id           10845 non-null  object
#  2   estimated_stock_pct  10845 non-null  float64
#  3   quantity             10845 non-null  float64
#  4   temperature          10845 non-null  float64
#  5   category             10845 non-null  object
#  6   unit_price           10845 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 677.8+ KB

# %% [markdown]
# Engineering features so that they are useful for the machine learning model

# %%
# Engineering features so that they are useful for the machine learning model
merged_df['timestamp_day_of_month'] = merged_df['timestamp'].dt.day
merged_df['timestamp_day_of_week'] = merged_df['timestamp'].dt.dayofweek
merged_df['timestamp_hour'] = merged_df['timestamp'].dt.hour
merged_df.drop(columns=['timestamp'], inplace=True)
merged_df.head()
# Out:
#                              product_id  estimated_stock_pct  quantity  \
# 0  00e120bb-89d6-4df5-bc48-a051148e3d03                 0.89       3.0
# 1  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0                 0.14       3.0
# 2  01ff0803-ae73-4234-971d-5713c97b7f4b                 0.67       0.0
# 3  0363eb21-8c74-47e1-a216-c37e565e5ceb                 0.82       0.0
# 4  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc                 0.05       0.0
#
#    temperature       category  unit_price  timestamp_day_of_month  \
# 0     -0.02885        kitchen       11.19                       1
# 1     -0.02885     vegetables        1.49                       1
# 2     -0.02885  baby products       14.19                       1
# 3     -0.02885      beverages       20.19                       1
# 4     -0.02885           pets        8.19                       1
#
#    timestamp_day_of_week  timestamp_hour
# 0                      1               9
# 1                      1               9
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10845 entries, 0 to 10844
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              10845 non-null  object
#  1   estimated_stock_pct     10845 non-null  float64
#  2   quantity                10845 non-null  float64
#  3   temperature             10845 non-null  float64
#  4   category                10845 non-null  object
#  5   unit_price              10845 non-null  float64
#  6   timestamp_day_of_month  10845 non-null  int64
#  7   timestamp_day_of_week   10845 non-null  int64
#  8   timestamp_hour          10845 non-null  int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 847.3+ KB

# %%
merged_df = pd.get_dummies(merged_df, columns=['category'])
merged_df.head()
# Out:
#                              product_id  estimated_stock_pct  quantity  \
# 0  00e120bb-89d6-4df5-bc48-a051148e3d03                 0.89       3.0
# 1  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0                 0.14       3.0
# 2  01ff0803-ae73-4234-971d-5713c97b7f4b                 0.67       0.0
# 3  0363eb21-8c74-47e1-a216-c37e565e5ceb                 0.82       0.0
# 4  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc                 0.05       0.0
#
#    temperature  unit_price  timestamp_day_of_month  timestamp_day_of_week  \
# 0     -0.02885       11.19                       1                      1
# 1     -0.02885        1.49                       1                      1
# 2     -0.02885       14.19                       1                      1
# 3     -0.02885       20.19                       1                      1
# 4     -0.02885        8.19                       1                      1
#
#    timestamp_hour  category_baby products  category_baked goods  ...  \
# ...

# %%
# Dropping the id column because it is not useful to modeling
merged_df.drop(columns=['product_id'], inplace=True)
merged_df.head()
# Out:
#    estimated_stock_pct  quantity  temperature  unit_price  \
# 0                 0.89       3.0     -0.02885       11.19
# 1                 0.14       3.0     -0.02885        1.49
# 2                 0.67       0.0     -0.02885       14.19
# 3                 0.82       0.0     -0.02885       20.19
# 4                 0.05       0.0     -0.02885        8.19
#
#    timestamp_day_of_month  timestamp_day_of_week  timestamp_hour  \
# 0                       1                      1               9
# 1                       1                      1               9
# 2                       1                      1               9
# 3                       1                      1               9
# 4                       1                      1               9
#
#    category_baby products  category_baked goods  category_baking  ...  \
# 0                       0                     0                0  ...
# 1                       0                     0                0  ...
# ...

# %% [markdown]
# ## - **Modeling**

# %% [markdown]
# Using the Random Forest Classifier Model, the K Nearest Neighbor, and the Logistic Regression Model to predict the stock using features engineered.

# %% [markdown]
# - Splitting the data in train validate and test for use with the 3 different models. Only train and validate will be used first. The test set will be used with the best model to perform on the validate dataset.

# %%
# Imports for modeling
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler

# %%
# Setting the input variables and the target variable
X = merged_df.drop(columns=['estimated_stock_pct'])
y = merged_df['estimated_stock_pct']
print(X.shape)
print(y.shape)

# %%
# Setting the number of folds of the regressor
K = 10
split = 0.75

# %%
# # Establishing a Baseline
# accuracy = []

# for fold in range(0, K):
#   # Create training and test samples
#   X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=split, random_state=42)

#   # Prepping the baseline DataFrames for evaluation
#   y_train = pd.DataFrame(y_train)
#   y_test = pd.DataFrame(y_test)

#   # Train model
#   trained_model = model.fit(X_train_scled, y_train)

#   # Generate predictions on test sample
#   y_pred = trained_model.predict(X_test_scaled)

#   # Compute accuracy, using mean absolute error
#   mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
#   accuracy.append(mae)
#   print(f"Fold {fold + 1}: MAE = {mae:.3f}")

# print(f"Average MAE: {(sum(accuracy) / len(accuracy)):.2f}")

# %%
# # Setting a baseline
# # We need y_train and y_validate to be dataframes to append the new columns with predicted values. 
# y_train = pd.DataFrame(y_train)
# y_validate = pd.DataFrame(y_validate)

# # 1. Predict G3_pred_mean
# G3_pred_mean = y_train['G3'].mean()
# y_train['G3_pred_mean'] = G3_pred_mean
# y_validate['G3_pred_mean'] = G3_pred_mean

# # 2. compute G3_pred_median
# G3_pred_median = y_train['G3'].median()
# y_train['G3_pred_median'] = G3_pred_median
# y_validate['G3_pred_median'] = G3_pred_median

# # 3. RMSE of G3_pred_mean
# rmse_train = mean_squared_error(y_train.G3, y_train.G3_pred_mean)**(1/2)
# rmse_validate = mean_squared_error(y_validate.G3, y_validate.G3_pred_mean)**(1/2)

# print("RMSE using Mean\nTrain/In-Sample: ", round(rmse_train, 2), 
#       "\nValidate/Out-of-Sample: ", round(rmse_validate, 2))

# # 4. RMSE of G3_pred_median
# rmse_train = mean_squared_error(y_train.G3, y_train.G3_pred_median)**(1/2)
# rmse_validate = mean_squared_error(y_validate.G3, y_validate.G3_pred_median)**(1/2)

# print("RMSE using Median\nTrain/In-Sample: ", round(rmse_train, 2), 
#       "\nValidate/Out-of-Sample: ", round(rmse_validate, 2))

# %%
accuracy = []

for fold in range(0, K):

  # Instantiate algorithm
  rf = RandomForestRegressor()
  scaler = StandardScaler()

  # Create training and test samples
  X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=split, random_state=42)

  # Scale X data, we scale the data because it helps the algorithm to converge
  # and helps the algorithm to not be greedy with large values
  scaler.fit(X_train)
  X_train_scaled = scaler.transform(X_train)
  X_test_scaled = scaler.transform(X_test)

  # Train model
  rf_model = rf.fit(X_train_scaled, y_train)

  # Generate predictions on test sample
  y_pred = rf_model.predict(X_test_scaled)

  # Compute accuracy, using mean absolute error
  mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
  accuracy.append(mae)
  print(f"Fold {fold + 1}: MAE = {mae:.3f}")

print(f"Average MAE: {(sum(accuracy) / len(accuracy)):.2f}")
# Out:
# Fold 1: MAE = 0.236
# Fold 2: MAE = 0.236
# Fold 3: MAE = 0.236
# Fold 4: MAE = 0.238
# Fold 5: MAE = 0.237
# Fold 6: MAE = 0.236
# Fold 7: MAE = 0.237
# Fold 8: MAE = 0.237
# Fold 9: MAE = 0.236
# Fold 10: MAE = 0.236
# Average MAE: 0.24

# %%
# Plotting the features importance
import matplotlib.pyplot as plt
import numpy as np

features = [i.split("__")[0] for i in X.columns]
importances = rf_model.feature_importances_
indices = np.argsort(importances)

fig, ax = plt.subplots(figsize=(10, 20))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %% [markdown]
# ## - Model with Logistic Regression

# %%
# Imports for Linear Regression modeling
from sklearn.linear_model import LinearRegression

# %%
accuracy = []
for fold in range(0, K):

  # Instantiate algorithm
  lr = LinearRegression(normalize=True)

  # Train model
  lr_model = lr.fit(X_train_scaled, y_train)

  # Generate predictions on test sample
  y_pred = trained_model.predict(X_test_scaled)

  # Compute accuracy, using mean absolute error
  mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
  accuracy.append(mae)
  print(f"Fold {fold + 1}: MAE = {mae:.3f}")

print(f"Average MAE: {(sum(accuracy) / len(accuracy)):.2f}")

# %%
# Plotting the features importance
features = [i.split("__")[0] for i in X.columns]
importances = lm_model.feature_importances_
indices = np.argsort(importances)

fig, ax = plt.subplots(figsize=(10, 20))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color=['red', 'yellow', 'black', 'blue', 'orange', 'green', 'cyan', '0.3', '0.7'], align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
